# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\nicha\Downloads\Employers_data.csv")

# %%
df.head()
# Out:
#    Employee_ID            Name  Age  Gender   Department  Job_Title  \
# 0            1    Merle Ingram   24  Female  Engineering   Engineer
# 1            2      John Mayes   56    Male        Sales  Executive
# 2            3    Carlos Wille   21    Male  Engineering     Intern
# 3            4  Michael Bryant   30    Male      Finance    Analyst
# 4            5   Paula Douglas   25  Female           HR    Analyst
#
#    Experience_Years Education_Level  Location  Salary
# 0                 1          Master    Austin   90000
# 1                33          Master   Seattle  195000
# 2                 1        Bachelor  New York   35000
# 3                 9        Bachelor  New York   75000
# 4                 2          Master   Seattle   70000

# %%
df.tail(2)
# Out:
#       Employee_ID            Name  Age  Gender   Department Job_Title  \
# 9998         9999  Margaret Gomez   37  Female  Engineering   Manager
# 9999        10000   Joan Sorensen   25  Female        Sales   Analyst
#
#       Experience_Years Education_Level       Location  Salary
# 9998                14          Master       New York  135000
# 9999                 4        Bachelor  San Francisco   70000

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.describe()
# Out:
#        Employee_ID           Age  Experience_Years         Salary
# count  10000.00000  10000.000000      10000.000000   10000.000000
# mean    5000.50000     35.455900         12.370900  115381.500000
# std     2886.89568     10.000213          9.148951   46066.139047
# min        1.00000     21.000000          0.000000   25000.000000
# 25%     2500.75000     27.000000          5.000000   70000.000000
# 50%     5000.50000     34.000000         10.000000  120000.000000
# 75%     7500.25000     43.000000         19.000000  150000.000000
# max    10000.00000     60.000000         37.000000  215000.000000

# %%
df.isnull().sum()
# Out:
# Employee_ID         0
# Name                0
# Age                 0
# Gender              0
# Department          0
# Job_Title           0
# Experience_Years    0
# Education_Level     0
# Location            0
# Salary              0
# dtype: int64

# %%
# Data Visualization Starts Now

# %%
age_counts = df['Age'].value_counts()

# %%
plt.figure(figsize=(10, 6))
age_counts.plot(kind='bar', color='red', edgecolor='black')
plt.title('Age Distribution', fontweight='bold')
plt.xlabel('Age', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
plt.xticks(rotation=0, fontweight='bold')
for spine in plt.gca().spines.values():
    spine.set_linewidth(2)
plt.show()

# %%
plt.figure(figsize=(10, 6))
gender_counts.plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
department_counts = df['Department'].value_counts()

# %%
plt.figure(figsize=(10, 6))
department_counts.plot(kind='bar',)
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
job_title_counts = df['Job_Title'].value_counts()

# %%
plt.figure(figsize=(10, 6))
job_title_counts.plot(kind='bar')
plt.title('Job Title Distribution')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.show()

# %%
education_counts = df['Education_Level'].value_counts()

# %%
plt.figure(figsize=(10, 6))
education_counts.plot(kind='bar')
plt.title('Education Level Distribution')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.show()

# %%
location_counts = df['Location'].value_counts()

# %%
plt.figure(figsize=(10, 6))
location_counts.plot(kind='bar', color = 'green')
plt.title('Location Distribution')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=15)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Experience_Years'], alpha=0.6, color = 'red')
plt.title('Scatter Plot of Age vs Experience Years')
plt.xlabel('Age')
plt.ylabel('Experience Years')
plt.grid(True)
plt.show()

# %%
education_counts = df.groupby('Department')['Education_Level'].value_counts().unstack()

# %%
education_counts.plot(kind='bar', stacked=True, figsize=(12, 7))
plt.title('Education Level by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Education Level')
plt.grid(axis='y')
plt.show()

# %%
sns.pairplot(df)
plt.title('Pair Plot of Numeric Features')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
correlation_matrix = numeric_df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar=True)
plt.title('Heatmap of Numeric Features')
plt.show()

# %%
sns.set(style="whitegrid")

# %%
# 1. Scatter plot for Salary vs. Experience_Years
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Experience_Years', y='Salary', alpha=0.6)
plt.title('Salary vs. Experience Years')
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()

# 2. Box plot for Salary vs. Gender
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Gender', y='Salary')
plt.title('Salary Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# 3. Box plot for Salary vs. Department
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Department', y='Salary')
plt.title('Salary Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# 4. Box plot for Salary vs. Education_Level
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Education_Level', y='Salary')
plt.title('Salary Distribution by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Salary')
plt.show()

# %%
df = df.drop(columns=['Name', 'Employee_ID'])

# %%
df_dummies = pd.get_dummies(df, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Assuming df_dummies is already defined

# Separate features and target variable
x = df_dummies.drop(columns=['Salary'])  # Features
y = df_dummies['Salary']                   # Target variable

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a Linear Regression model
model = LinearRegression()

# Fit the model
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Calculate and print Mean Squared Error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 17375021.621597145
# R-squared: 0.9917562580370475

# %%
# An R-squared value of approximately 0.99 indicates a very high level of explanatory power for the model. This means that about 99.2% of the variance in the target variable (salary) can be explained by the independent variables included in the model.
#Model Fit:
#Such a high R-squared suggests that the model fits the data exceptionally well, making it likely that the predictors are capturing the underlying trends in the salary data.
#Overfitting Risk:
#However, an extremely high R-squared can also raise concerns about overfitting, especially if the model is too complex or if it includes too many predictors relative to the number of observations. This means the model may perform well on the training data but could struggle to generalize to new, unseen data.
